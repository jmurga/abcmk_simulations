# %%
import tensorflow as tf
from tensorflow import keras

# %%
from tensorflow.keras import datasets, Sequential

# %%
from tensorflow.keras.layers import Flatten, Dense

# %%
modelo = Sequential()
modelo.add(Flatten(input_shape=(1,10)))

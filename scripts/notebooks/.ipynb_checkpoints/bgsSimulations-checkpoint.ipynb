# %%
import sys
import pandas as pd
import numpy as np
from multiprocessing import Pool
from plotnine import *
import plotnine as plt

PATH = "/home/jmurga/mkt/202004" 
sys.path.insert(0, PATH + '/scripts/src/')  
from pyAmkt import *
from slimParser import *

# %% [markdown]
# Create the output directory. You should change the directory tree if you clone the github repo

# %%
# !mkdir -p /home/jmurga/mkt/202004/rawData/simulations /home/jmurga/mkt/202004/rawData/summStat /home/jmurga/mkt/202004/rawData/dofe/noDemogx

# %% [markdown]
# # No demography simulations

# %% [markdown]
# ## Solving values to simulate with Analytical.jl

# %%
# !which julia

# %% [markdown]
# Add the proper packages to your Julia session

# %%
# !julia -e 'using Pkg;Pkg.add("CSV");Pkg.add("DataFrames");Pkg.add(PackageSpec(path="https://github.com/jmurga/Analytical.jl"))'

# %%
# !julia /home/jmurga/mkt/202004/scripts/src/simTable.jl 500 200000 bgsTable

# %%
simTable = pd.read_csv(PATH + "/rawData/simulations/bgsTable.tsv", sep='\t')
simTable['path'] = simTable.apply(lambda row: "/home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_" + str(row['alpha']) + "_" + str(row['alphaW']) + "_" + str(np.round(row['B'],4)),axis=1)
simTable['analysis']= 'noDemog'

# %% [markdown]
# I test two cases in the notebook case I select one row from simTable

# %% [markdown]
# ## Running SLiM

# %% [markdown]
# Generating replicates and folders. It depends on GNU parallel tool and SLiM

# %%
nSamples=500
binnedSfs=(nSamples*2)-1

# %%
runSlim(recipe="/home/jmurga/mkt/202004/scripts/slimRecipes/bgs.slim",simTable=tmpSim,pSize=500,codingLength=2000,strongStrength=500,weaklyStrength=10,bins=binnedSfs,replicas=[1,50000],threads=8,slimPath="/home/jmurga/.conda/envs/abcmk/bin/slim",parallelPath="/home/jmurga/.conda/envs/abcmk/bin/parallel")

# %%
runSlim(recipe="/home/jmurga/mkt/202004/scripts/slimRecipes/bgs.slim",simTable=tmpSim.tail(1),pSize=1000,codingLength=10000,strongStrength=500,weaklyStrength=10,bins=binnedSfs,replicas=[1,10000],threads=5,slimPath="/home/jmurga/.conda/envs/abcmk/bin/slim",parallelPath="/home/jmurga/.conda/envs/abcmk/bin/parallel")

# %% [markdown]
# ## Processing simulated data

# %% [markdown]
# ### All simulations

# %%
simTable=simTable.tail(3).head(1);simTable
# Out:
#       bgsThetaF     pposL     pposH  alphaW  alpha  estimation      B  \
# 9  8.220000e-10  0.003896  0.000397     0.1    0.4     0.40147  0.999
#
#                                                 path
# 9  /home/jmurga/mkt/202004/rawData/simulations/no...

# %%
for index,row in simTable.iterrows():
    print(row.path)
    parsePolDiv(row.path,500)
# Out:
# /home/jmurga/mkt/202004/rawData/simulations/noDemog/noDemog_0.4_0.1_0.999
# 100%|██████████| 50000/50000 [01:27<00:00, 572.92it/s]

# %%
df,dfAlpha = saveSimulatedAlphas(simTable);dfAlpha
dfAlpha
# Out:
# /home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.1_0.2
# /home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.2_0.2
# /home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.3_0.2
# /home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.1_0.4
# /home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.2_0.4
# /home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.3_0.4
# /home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.1_0.8
# /home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.2_0.8
# /home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.3_0.8
# /home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.1_0.999
# /home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.2_0.999
# /home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.3_0.999
#             f    alphas      B  alphaW                    sfs  \
# 0    0.001001 -0.647849  0.200     0.1  Neutral + deleterious
# 1    0.002002 -0.407424  0.200     0.1  Neutral + deleterious
# 2    0.003003 -0.332796  0.200     0.1  Neutral + deleterious
# 3    0.004004 -0.281825  0.200     0.1  Neutral + deleterious
# 4    0.005005 -0.245331  0.200     0.1  Neutral + deleterious
# ..        ...       ...    ...     ...                    ...
# 994  0.995996  0.066204  0.999     0.3            All alleles
# 995  0.996997  0.084752  0.999     0.3            All alleles
# 996  0.997998  0.106332  0.999     0.3            All alleles
# 997  0.998999  0.035028  0.999     0.3            All alleles
# 998  1.000000  0.116046  0.999     0.3            All alleles
#
#                       path analysis
# 0      noDemog_0.4_0.1_0.2  noDemog
# 1      noDemog_0.4_0.1_0.2  noDemog
# 2      noDemog_0.4_0.1_0.2  noDemog
# 3      noDemog_0.4_0.1_0.2  noDemog
# 4      noDemog_0.4_0.1_0.2  noDemog
# ..                     ...      ...
# 994  noDemog_0.4_0.3_0.999  noDemog
# 995  noDemog_0.4_0.3_0.999  noDemog
# 996  noDemog_0.4_0.3_0.999  noDemog
# 997  noDemog_0.4_0.3_0.999  noDemog
# 998  noDemog_0.4_0.3_0.999  noDemog
#
# [23976 rows x 7 columns]

# %%
df = df.round(3)

# %%
df.to_csv(PATH + '/results/simulations/alphasSimulations/simulatedAlphas.tsv',index=False,sep='\t',header=True)

# %%
dfAlpha.to_csv(PATH + '/results/simulations/alphasSimulations/simulatedToPlotAll.tsv',index=False,sep='\t',header=True)

# %%
dfAlpha['path'] = pd.Categorical(dfAlpha['path'], ["noDemog_0.4_0.1_0.2","noDemog_0.4_0.2_0.2","noDemog_0.4_0.3_0.2","noDemog_0.4_0.1_0.4","noDemog_0.4_0.2_0.4","noDemog_0.4_0.3_0.4","noDemog_0.4_0.1_0.8","noDemog_0.4_0.2_0.8","noDemog_0.4_0.3_0.8","noDemog_0.4_0.1_0.999","noDemog_0.4_0.2_0.999","noDemog_0.4_0.3_0.999"])

# %%
plt.options.figure_size=(8,12)
p = (ggplot(dfAlpha, aes(x='f',y='alphas',color='sfs')) + geom_line() + facet_wrap('~path',ncol=3) + ylim(-0.5,0.5)) + scale_color_manual({'All alleles':'gray',"Neutral + deleterious":'#ab2710'}) + theme_bw();p
# Out:
# /home/jmurga/.conda/lib/python3.8/site-packages/plotnine/geoms/geom_path.py:75: PlotnineWarning: geom_path: Removed 1 rows containing missing values.
# <ggplot: (8750963271277)>

# %%
ggsave(p,"/home/jmurga/mkt/202004/results/simulations/alphasSimulations/simulatedAlphas.jpg",dpi=600)
# Out:
# /home/jmurga/.conda/lib/python3.8/site-packages/plotnine/ggplot.py:727: PlotnineWarning: Saving 8 x 12 in image.
# /home/jmurga/.conda/lib/python3.8/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: /home/jmurga/mkt/202004/results/simulations/alphasSimulations/simulatedAlphas.jpg
# /home/jmurga/.conda/lib/python3.8/site-packages/plotnine/geoms/geom_path.py:75: PlotnineWarning: geom_path: Removed 1 rows containing missing values.

# %%
df,dfAlpha = saveSimulatedAlphas(simTable,bins=100);dfAlpha
# Out:
# /home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.1_0.2
# /home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.2_0.2
# /home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.3_0.2
# /home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.1_0.4
# /home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.2_0.4
# /home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.3_0.4
# /home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.1_0.8
# /home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.2_0.8
# /home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.3_0.8
# /home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.1_0.999
# /home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.2_0.999
# /home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.3_0.999
#         f    alphas      B  alphaW                    sfs  \
# 0    0.01 -0.417901  0.200     0.1  Neutral + deleterious
# 1    0.02 -0.187314  0.200     0.1  Neutral + deleterious
# 2    0.03 -0.129683  0.200     0.1  Neutral + deleterious
# 3    0.04 -0.093737  0.200     0.1  Neutral + deleterious
# 4    0.05 -0.070078  0.200     0.1  Neutral + deleterious
# ..    ...       ...    ...     ...                    ...
# 194  1.95  0.112654  0.999     0.3            All alleles
# 195  1.96  0.085346  0.999     0.3            All alleles
# 196  1.97  0.044968  0.999     0.3            All alleles
# 197  1.98  0.130579  0.999     0.3            All alleles
# 198  1.99  0.095017  0.999     0.3            All alleles
#
#                       path analysis
# 0      noDemog_0.4_0.1_0.2  noDemog
# 1      noDemog_0.4_0.1_0.2  noDemog
# 2      noDemog_0.4_0.1_0.2  noDemog
# 3      noDemog_0.4_0.1_0.2  noDemog
# 4      noDemog_0.4_0.1_0.2  noDemog
# ..                     ...      ...
# 194  noDemog_0.4_0.3_0.999  noDemog
# 195  noDemog_0.4_0.3_0.999  noDemog
# 196  noDemog_0.4_0.3_0.999  noDemog
# 197  noDemog_0.4_0.3_0.999  noDemog
# 198  noDemog_0.4_0.3_0.999  noDemog
#
# [4776 rows x 7 columns]

# %%
dfAlpha['path'] = pd.Categorical(dfAlpha['path'], ["noDemog_0.4_0.1_0.2","noDemog_0.4_0.2_0.2","noDemog_0.4_0.3_0.2","noDemog_0.4_0.1_0.4","noDemog_0.4_0.2_0.4","noDemog_0.4_0.3_0.4","noDemog_0.4_0.1_0.8","noDemog_0.4_0.2_0.8","noDemog_0.4_0.3_0.8","noDemog_0.4_0.1_0.999","noDemog_0.4_0.2_0.999","noDemog_0.4_0.3_0.999"])

# %%
dfAlpha.to_csv(PATH + '/results/simulations/alphasSimulations/simulatedToPlotReduced.tsv',index=False,sep='\t',header=True)

# %%
plt.options.figure_size=(8,12)
p = (ggplot(dfAlpha, aes(x='f',y='alphas',color='sfs')) + geom_line() + facet_wrap('~path',ncol=3) + ylim(-0.5,0.5)) + scale_color_manual({'All alleles':'gray',"Neutral + deleterious":'#ab2710'}) + theme_bw();p
# Out:
# <ggplot: (8750963274409)>

# %%
ggsave(p,"/home/jmurga/mkt/202004/results/simulations/alphasSimulations/simulatedAlphasReduced.jpg",dpi=300)
# Out:
# /home/jmurga/.conda/lib/python3.8/site-packages/plotnine/ggplot.py:727: PlotnineWarning: Saving 8 x 12 in image.
# /home/jmurga/.conda/lib/python3.8/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: /home/jmurga/mkt/202004/results/simulations/alphasSimulations/simulatedAlphasReduced.jpg
# /home/jmurga/.conda/lib/python3.8/site-packages/plotnine/geoms/geom_path.py:75: PlotnineWarning: geom_path: Removed 1 rows containing missing values.

# %% [markdown]
# ### Convert SFS to DOFE and bootstrap

# %%
    for index, row in simTable.tail(3).head(1).iterrows():
        print(row.path)
        parseBootstrapPolDiv(path=row.path,N=500,output="/home/jmurga/mkt/202004/rawData/dofe/noDemog/",sample=40000,replicas=1,dofe=True,bins=10,nthreads=12)
# Out:
# '/home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.1_0.2'
# '/home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.2_0.2'
# '/home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.3_0.2'
# '/home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.1_0.4'
# '/home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.2_0.4'
# '/home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.3_0.4'
# '/home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.1_0.8'
# '/home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.2_0.8'
# '/home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.3_0.8'
# '/home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.1_0.999'
# '/home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.2_0.999'
# '/home/jmurga/mkt/202004/rawData/simulations/noDemog/ne500/noDemog_0.4_0.3_0.999'

# %% [markdown]
# # Tennesen model

# %% [markdown]
# ## Solving values to simulate with Analytical.jl

# %%
# !which julia

# %%
# !julia /home/jmurga/mkt/202004/scripts/src/simTable.jl 7310 100000 tennensen.tsv

# %% [markdown]
# ## Solving values to simulate with Analytical.jl

# %%
simTable = pd.read_csv(PATH + "/rawData/simulations/tennesen.tsv", sep='\t')
simTable['path'] = simTable.apply(lambda row: "/home/jmurga/mkt/202004/rawData/simulations/isolationRescaled/isolation_" + str(row['alpha']) + "_" + str(row['alphaW']) + "_" + str(np.round(row['B'],4)),axis=1)
simTable['analysis'] = 'isolation'

# %% [markdown]
# To test just one case I select one row from simTable

# %%
tmpSim = simTable.tail(1)

# %% [markdown]
# ## Running SLiM

# %% [markdown]
# Generating replicates and folders. It depends on GNU parallel tool and SLiM

# %%
nSamples=661
binnedSfs = (nSamples * 2) - 1

# %%
runSlim(recipe="/home/jmurga/mkt/202004/scripts/slimRecipes/tennesen.slim",simTable=tmpSim,pSize=500,codingLength=2000,strongStrength=500,weaklyStrength=10,sSize=nSamples,replicas=[1,50000],threads=7,slimPath="/home/jmurga/.conda/envs/abcmk/bin/slim",parallelPath="/home/jmurga/.conda/envs/abcmk/bin/parallel")

# %% [markdown]
# ## Processing simulated data

# %%
for index,row in simTable.iterrows():
    parsePolDiv(row.path,661,7)

# %%
df,dfAlpha = saveSimulatedAlphas(table=simTable);dfAlpha['B'] = round(dfAlpha['B'],3);
# Out:
# /home/jmurga/mkt/202004/rawData/simulations/isolationRescaled/isolation_0.4_0.1_0.2
# /home/jmurga/mkt/202004/rawData/simulations/isolationRescaled/isolation_0.4_0.2_0.2
# /home/jmurga/mkt/202004/rawData/simulations/isolationRescaled/isolation_0.4_0.3_0.2
# /home/jmurga/mkt/202004/rawData/simulations/isolationRescaled/isolation_0.4_0.1_0.4
# /home/jmurga/mkt/202004/rawData/simulations/isolationRescaled/isolation_0.4_0.2_0.4
# /home/jmurga/mkt/202004/rawData/simulations/isolationRescaled/isolation_0.4_0.3_0.4
# /home/jmurga/mkt/202004/rawData/simulations/isolationRescaled/isolation_0.4_0.1_0.8
# /home/jmurga/mkt/202004/rawData/simulations/isolationRescaled/isolation_0.4_0.2_0.8
# /home/jmurga/mkt/202004/rawData/simulations/isolationRescaled/isolation_0.4_0.3_0.8
# /home/jmurga/mkt/202004/rawData/simulations/isolationRescaled/isolation_0.4_0.1_0.999
# /home/jmurga/mkt/202004/rawData/simulations/isolationRescaled/isolation_0.4_0.2_0.999
# /home/jmurga/mkt/202004/rawData/simulations/isolationRescaled/isolation_0.4_0.3_0.999

# %%
df
# Out:
#    trueAlpha  asymp_nopos     asymp  analyticalEstimation  \
# 0   0.208582     0.159860  0.120182               0.25688
# 0   0.191582     0.183590  0.105001               0.23086
# 0   0.177178     0.164698  0.042776               0.20285
# 0   0.251018     0.158935       NaN               0.31311
# 0   0.265350     0.245319  0.148530               0.29542
# 0   0.249088     0.248128  0.095686               0.27673
# 0   0.359544     0.320086  0.263485               0.37851
# 0   0.350316     0.321598       NaN               0.37433
# 0   0.341459     0.323675       NaN               0.37008
# 0   0.389288     0.357205  0.297101               0.40134
# 0   0.381138     0.354331       NaN               0.40248
# 0   0.363720     0.358096       NaN               0.40362
#
#                       path   analysis
# 0    isolation_0.4_0.1_0.2  isolation
# 0    isolation_0.4_0.2_0.2  isolation
# 0    isolation_0.4_0.3_0.2  isolation
# 0    isolation_0.4_0.1_0.4  isolation
# 0    isolation_0.4_0.2_0.4  isolation
# 0    isolation_0.4_0.3_0.4  isolation
# 0    isolation_0.4_0.1_0.8  isolation
# 0    isolation_0.4_0.2_0.8  isolation
# 0    isolation_0.4_0.3_0.8  isolation
# 0  isolation_0.4_0.1_0.999  isolation
# 0  isolation_0.4_0.2_0.999  isolation
# 0  isolation_0.4_0.3_0.999  isolation

# %%
dfAlpha['group'] = dfAlpha.path + ": " + dfAlpha.sfs
dfAlpha['path']  = pd.Categorical(dfAlpha.path, categories=pd.unique(dfAlpha.path))

# %%
plt.options.figure_size=(10,7)
p = (ggplot(dfAlpha, aes(x='f',y='alphas',color='sfs')) + geom_line() + facet_wrap('~path',ncol=3,scales='free_x') + ylim(-0.5,0.5) + scale_color_manual({'All alleles':'gray',"Neutral + deleterious":'#ab2710'}) + theme_bw() + theme(legend_position='bottom'))
ggsave(p,filename=PATH + "/results/simulations/slim/isolation/isolationRecaledSimulations.svg")
# Out:
# /home/jmurga/.conda/lib/python3.8/site-packages/plotnine/ggplot.py:727: PlotnineWarning: Saving 10 x 7 in image.
# /home/jmurga/.conda/lib/python3.8/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: /home/jmurga/mkt/202004/results/simulations/slim/isolation/isolationRecaledSimulations.svg
# /home/jmurga/.conda/lib/python3.8/site-packages/plotnine/facets/facet.py:555: PlotnineWarning: If you need more space for the y-axis tick text use ... + theme(subplots_adjust={'hspace': 0.25}). Choose an appropriate value for 'hspace'
# /home/jmurga/.conda/lib/python3.8/site-packages/plotnine/geoms/geom_path.py:75: PlotnineWarning: geom_path: Removed 1 rows containing missing values.

# %%
p
# Out:
# /home/jmurga/.conda/lib/python3.8/site-packages/plotnine/facets/facet.py:555: PlotnineWarning: If you need more space for the y-axis tick text use ... + theme(subplots_adjust={'hspace': 0.25}). Choose an appropriate value for 'hspace'
# /home/jmurga/.conda/lib/python3.8/site-packages/plotnine/geoms/geom_path.py:75: PlotnineWarning: geom_path: Removed 1 rows containing missing values.
# <ggplot: (8750999579118)>

# %% [markdown]
# # Tennesen two epochs model

# %% [markdown]
# We have modified the tennesen model to perform the isolation model without the final exponential at African population. We move to a two epoch model: a stable population experimented an instantaneous change N generations ago.

# %% [markdown]
# ## Running SLiM

# %% [markdown]
# ## Processig simulated data

# %%
simTable = pd.read_csv(PATH + "/rawData/simulations/tennesen.tsv", sep='\t')
simTable['path'] = simTable.apply(lambda row: "/home/jmurga/mkt/202004/rawData/simulations/twoepochs/twoepochs_" + str(row['alpha']) + "_" + str(row['alphaW']) + "_" + str(np.round(row['B'],4)),axis=1)
simTable['analysis'] = 'twoepochs'

# %% [markdown]
# ## Processing simulated data

# %% [markdown]
# Pooling the simulations into one SFS and divergence file

# %%
for index,row in simTable.iterrows():
    print(row.path)
    parsePolDiv(row.path,661,2)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-4-9c94e95bf0ba>", line 2, in <module>
#     parsePolDiv(row.path,661,5)
#   File "/home/jmurga/mkt/202004/scripts/src/slimParser.py", line 55, in parsePolDiv
#     lSfs, lDiv = zip(*pool.starmap(openFiles,list(zip(dafFiles,divFiles))))
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/pool.py", line 372, in starmap
#     return self._map_async(func, iterable, starmapstar, chunksize).get()
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/pool.py", line 765, in get
#     self.wait(timeout)
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/pool.py", line 762, in wait
#     self._event.wait(timeout)
#   File "/home/jmurga/.conda/lib/python3.8/threading.py", line 558, in wait
#     signaled = self._cond.wait(timeout)
#   File "/home/jmurga/.conda/lib/python3.8/threading.py", line 302, in wait
#     waiter.acquire()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1170, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/jmurga/.conda/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/jmurga/.conda/lib/python3.8/inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/jmurga/.conda/lib/python3.8/inspect.py", line 705, in getsourcefile
#     if os.path.exists(filename):
#   File "/home/jmurga/.conda/lib/python3.8/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-4-9c94e95bf0ba>", line 2, in <module>
#     parsePolDiv(row.path,661,5)
#   File "/home/jmurga/mkt/202004/scripts/src/slimParser.py", line 55, in parsePolDiv
#     lSfs, lDiv = zip(*pool.starmap(openFiles,list(zip(dafFiles,divFiles))))
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/pool.py", line 372, in starmap
#     return self._map_async(func, iterable, starmapstar, chunksize).get()
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/pool.py", line 765, in get
#     self.wait(timeout)
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/pool.py", line 762, in wait
#     self._event.wait(timeout)
#   File "/home/jmurga/.conda/lib/python3.8/threading.py", line 558, in wait
#     signaled = self._cond.wait(timeout)
#   File "/home/jmurga/.conda/lib/python3.8/threading.py", line 302, in wait
#     waiter.acquire()
# KeyboardInterrupt
# Process ForkPoolWorker-21:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3338, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3435, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1151, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1170, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/jmurga/.conda/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/jmurga/.conda/lib/python3.8/inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/jmurga/.conda/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/jmurga/.conda/lib/python3.8/inspect.py", line 751, in getmodule
#     f = getabsfile(module)
#   File "/home/jmurga/.conda/lib/python3.8/inspect.py", line 720, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/home/jmurga/.conda/lib/python3.8/inspect.py", line 705, in getsourcefile
#     if os.path.exists(filename):
#   File "/home/jmurga/.conda/lib/python3.8/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# Process ForkPoolWorker-23:
# Process ForkPoolWorker-22:
# Traceback (most recent call last):
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-4-9c94e95bf0ba>", line 2, in <module>
#     parsePolDiv(row.path,661,5)
#   File "/home/jmurga/mkt/202004/scripts/src/slimParser.py", line 55, in parsePolDiv
#     lSfs, lDiv = zip(*pool.starmap(openFiles,list(zip(dafFiles,divFiles))))
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/pool.py", line 372, in starmap
#     return self._map_async(func, iterable, starmapstar, chunksize).get()
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/pool.py", line 765, in get
#     self.wait(timeout)
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/pool.py", line 762, in wait
#     self._event.wait(timeout)
#   File "/home/jmurga/.conda/lib/python3.8/threading.py", line 558, in wait
#     signaled = self._cond.wait(timeout)
#   File "/home/jmurga/.conda/lib/python3.8/threading.py", line 302, in wait
#     waiter.acquire()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3338, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3435, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1151, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2923, in _run_cell
#     return runner(coro)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3146, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3357, in run_ast_nodes
#     self.showtraceback()
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1211, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1151, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-4-9c94e95bf0ba>", line 2, in <module>
#     parsePolDiv(row.path,661,5)
#   File "/home/jmurga/mkt/202004/scripts/src/slimParser.py", line 55, in parsePolDiv
#     lSfs, lDiv = zip(*pool.starmap(openFiles,list(zip(dafFiles,divFiles))))
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/pool.py", line 372, in starmap
#     return self._map_async(func, iterable, starmapstar, chunksize).get()
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/pool.py", line 765, in get
#     self.wait(timeout)
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/pool.py", line 762, in wait
#     self._event.wait(timeout)
#   File "/home/jmurga/.conda/lib/python3.8/threading.py", line 558, in wait
#     signaled = self._cond.wait(timeout)
#   File "/home/jmurga/.conda/lib/python3.8/threading.py", line 302, in wait
#     waiter.acquire()
# Traceback (most recent call last):
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/jmurga/mkt/202004/scripts/src/slimParser.py", line 319, in openFiles
#     d = pd.read_csv(divFile, sep='\t').to_numpy().flatten()
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/io/parsers.py", line 686, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/io/parsers.py", line 452, in _read
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/io/parsers.py", line 946, in __init__
#     self._make_engine(self.engine)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/io/parsers.py", line 1178, in _make_engine
#     self._engine = CParserWrapper(self.f, **self.options)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1170, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/jmurga/.conda/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/jmurga/.conda/lib/python3.8/inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/jmurga/.conda/lib/python3.8/inspect.py", line 705, in getsourcefile
#     if os.path.exists(filename):
#   File "/home/jmurga/.conda/lib/python3.8/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/io/parsers.py", line 2008, in __init__
#     self._reader = parsers.TextReader(src, **kwds)
#   File "pandas/_libs/parsers.pyx", line 382, in pandas._libs.parsers.TextReader.__cinit__
#   File "pandas/_libs/parsers.pyx", line 620, in pandas._libs.parsers.TextReader._setup_parser_source
#   File "/home/jmurga/.conda/lib/python3.8/gzip.py", line 173, in __init__
#     fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
# KeyboardInterrupt
# Process ForkPoolWorker-28:
# Process ForkPoolWorker-26:
# Process ForkPoolWorker-27:
# Process ForkPoolWorker-24:
# Process ForkPoolWorker-25:
# Traceback (most recent call last):
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/jmurga/mkt/202004/scripts/src/slimParser.py", line 316, in openFiles
#     daf = pd.read_csv(sfsFile, sep='\t')
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/io/parsers.py", line 686, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/io/parsers.py", line 458, in _read
#     data = parser.read(nrows)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/io/parsers.py", line 1196, in read
#     ret = self._engine.read(nrows)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/io/parsers.py", line 2216, in read
#     data = sorted(data.items())
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/jmurga/mkt/202004/scripts/src/slimParser.py", line 319, in openFiles
#     d = pd.read_csv(divFile, sep='\t').to_numpy().flatten()
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/io/parsers.py", line 686, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/home/jmurga/mkt/202004/scripts/src/slimParser.py", line 321, in openFiles
#     return(daf.to_numpy()[:,1:],d)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/io/parsers.py", line 458, in _read
#     data = parser.read(nrows)
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/core/frame.py", line 1371, in to_numpy
#     result = self._mgr.as_array(
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/core/internals/managers.py", line 853, in as_array
#     arr = self._interleave(dtype=dtype, na_value=na_value)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/io/parsers.py", line 1211, in read
#     df = DataFrame(col_dict, columns=columns, index=index)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/core/internals/managers.py", line 871, in _interleave
#     dtype = _interleaved_dtype(self.blocks)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/core/frame.py", line 468, in __init__
#     mgr = init_dict(data, index, columns, dtype=dtype)
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/core/internals/managers.py", line 1886, in _interleaved_dtype
#     return find_common_type([b.dtype for b in blocks])
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/core/internals/construction.py", line 283, in init_dict
#     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/core/dtypes/cast.py", line 1463, in find_common_type
#     if len(types) == 0:
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/core/internals/construction.py", line 83, in arrays_to_mgr
#     arrays = _homogenize(arrays, index, dtype)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/core/internals/construction.py", line 351, in _homogenize
#     val = sanitize_array(
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/core/construction.py", line 428, in sanitize_array
#     subarr = _try_cast(data, dtype, copy, raise_cast_failure)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/core/construction.py", line 558, in _try_cast
#     subarr = maybe_cast_to_datetime(arr, dtype)
# KeyboardInterrupt
#   File "/home/jmurga/.conda/lib/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/core/dtypes/cast.py", line 1441, in maybe_cast_to_datetime
#     value = maybe_infer_to_datetimelike(value)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/core/dtypes/cast.py", line 1217, in maybe_infer_to_datetimelike
#     if isinstance(
# KeyboardInterrupt
#   File "/home/jmurga/mkt/202004/scripts/src/slimParser.py", line 317, in openFiles
#     daf[['pi_nopos']] = daf.iloc[:,1]-daf.iloc[:,3]
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/core/frame.py", line 3037, in __setitem__
#     self._setitem_array(key, value)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/core/frame.py", line 3068, in _setitem_array
#     indexer = self.loc._get_listlike_indexer(
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1249, in _get_listlike_indexer
#     indexer = ax.get_indexer_for(keyarr)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 4713, in get_indexer_for
#     return self.get_indexer(target, **kwargs)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 2978, in get_indexer
#     if not is_dtype_equal(self.dtype, target.dtype):
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/core/dtypes/common.py", line 635, in is_dtype_equal
#     try:
# KeyboardInterrupt
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3338, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3435, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1151, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1170, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/jmurga/.conda/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/jmurga/.conda/lib/python3.8/inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/jmurga/.conda/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/jmurga/.conda/lib/python3.8/inspect.py", line 751, in getmodule
#     f = getabsfile(module)
#   File "/home/jmurga/.conda/lib/python3.8/inspect.py", line 720, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/home/jmurga/.conda/lib/python3.8/inspect.py", line 705, in getsourcefile
#     if os.path.exists(filename):
#   File "/home/jmurga/.conda/lib/python3.8/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
#   File "/home/jmurga/mkt/202004/scripts/src/slimParser.py", line 319, in openFiles
#     d = pd.read_csv(divFile, sep='\t').to_numpy().flatten()
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/io/parsers.py", line 686, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/io/parsers.py", line 458, in _read
#     data = parser.read(nrows)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/io/parsers.py", line 1205, in read
#     index = RangeIndex(self._currow, self._currow + new_rows)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/core/indexes/range.py", line 102, in __new__
#     start = ensure_python_int(start) if start is not None else 0
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/pandas/core/dtypes/common.py", line 171, in ensure_python_int
#     new_value = int(value)
# KeyboardInterrupt
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1170, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/jmurga/.conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/jmurga/.conda/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/jmurga/.conda/lib/python3.8/inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/jmurga/.conda/lib/python3.8/inspect.py", line 705, in getsourcefile
#     if os.path.exists(filename):
#   File "/home/jmurga/.conda/lib/python3.8/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt

# %% [markdown]
# Original aMK analysis. We have performed the analysis accounting or not for weakly beneficial at the SFS

# %%
df,dfAlpha = saveSimulatedAlphas(table=simTable,cumulative=True)

# %%
df
# Out:
#    trueAlpha  asymp_nopos     asymp  analyticalEstimation  \
# 0   0.209041     0.232787  0.192688               0.25688
# 0   0.193354     0.195878  0.114648               0.23086
# 0   0.173781     0.158413  0.042693               0.20285
# 0   0.288279     0.264272  0.221509               0.31311
# 0   0.271031     0.242583  0.157710               0.29542
# 0   0.249751     0.231917  0.088803               0.27673
# 0   0.382501     0.385070  0.329757               0.37851
# 0   0.367389     0.352082  0.250892               0.37433
# 0   0.349036     0.330239  0.128088               0.37008
# 0   0.418466     0.391271  0.343344               0.40134
# 0   0.400415     0.402052  0.294304               0.40248
# 0   0.383705     0.388759  0.228128               0.40362
#
#                       path   analysis
# 0    twoepochs_0.4_0.1_0.2  twoepochs
# 0    twoepochs_0.4_0.2_0.2  twoepochs
# 0    twoepochs_0.4_0.3_0.2  twoepochs
# 0    twoepochs_0.4_0.1_0.4  twoepochs
# 0    twoepochs_0.4_0.2_0.4  twoepochs
# 0    twoepochs_0.4_0.3_0.4  twoepochs
# 0    twoepochs_0.4_0.1_0.8  twoepochs
# 0    twoepochs_0.4_0.2_0.8  twoepochs
# 0    twoepochs_0.4_0.3_0.8  twoepochs
# 0  twoepochs_0.4_0.1_0.999  twoepochs
# 0  twoepochs_0.4_0.2_0.999  twoepochs
# 0  twoepochs_0.4_0.3_0.999  twoepochs

# %%
dfAlpha[(dfAlpha.path=='twoepochs_0.4_0.1_0.999') & (dfAlpha.sfs == 'All alleles')]
# Out:
#            f    alphas      B  alphaW          sfs                     path  \
# 0   0.025641  0.151191  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 1   0.051282  0.252408  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 2   0.076923  0.287987  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 3   0.102564  0.307918  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 4   0.128205  0.324243  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 5   0.153846  0.335075  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 6   0.179487  0.339672  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 7   0.205128  0.347945  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 8   0.230769  0.351739  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 9   0.256410  0.357128  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 10  0.282051  0.359006  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 11  0.307692  0.362757  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 12  0.333333  0.364253  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 13  0.358974  0.363503  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 14  0.384615  0.363010  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 15  0.410256  0.363831  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 16  0.435897  0.362550  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 17  0.461538  0.362630  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 18  0.487179  0.362298  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 19  0.512821  0.360638  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 20  0.538462  0.356599  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 21  0.564103  0.356814  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 22  0.589744  0.358327  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 23  0.615385  0.353435  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 24  0.641026  0.355533  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 25  0.666667  0.351198  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 26  0.692308  0.348476  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 27  0.717949  0.344447  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 28  0.743590  0.346492  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 29  0.769231  0.342243  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 30  0.794872  0.338867  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 31  0.820513  0.340105  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 32  0.846154  0.324508  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 33  0.871795  0.325021  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 34  0.897436  0.317024  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 35  0.923077  0.300208  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 36  0.948718  0.304804  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 37  0.974359  0.280714  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
# 38  1.000000  0.266165  0.999     0.1  All alleles  twoepochs_0.4_0.1_0.999
#
#      analysis
# 0   twoepochs
# 1   twoepochs
# 2   twoepochs
# 3   twoepochs
# 4   twoepochs
# 5   twoepochs
# 6   twoepochs
# 7   twoepochs
# 8   twoepochs
# 9   twoepochs
# 10  twoepochs
# 11  twoepochs
# 12  twoepochs
# 13  twoepochs
# 14  twoepochs
# 15  twoepochs
# 16  twoepochs
# 17  twoepochs
# 18  twoepochs
# 19  twoepochs
# 20  twoepochs
# 21  twoepochs
# 22  twoepochs
# 23  twoepochs
# 24  twoepochs
# 25  twoepochs
# 26  twoepochs
# 27  twoepochs
# 28  twoepochs
# 29  twoepochs
# 30  twoepochs
# 31  twoepochs
# 32  twoepochs
# 33  twoepochs
# 34  twoepochs
# 35  twoepochs
# 36  twoepochs
# 37  twoepochs
# 38  twoepochs

# %% [markdown]
# Plotting $\alpha_{(x)}$

# %%
dfAlpha['B'] = round(dfAlpha['B'],3)
dfAlpha['group'] = dfAlpha.path + ": " + dfAlpha.sfs
dfAlpha['path']  = pd.Categorical(dfAlpha.path, categories=pd.unique(dfAlpha.path))

# %%
plt.options.figure_size=(10,7)
p = (ggplot(dfAlpha, aes(x='f',y='alphas',color='sfs')) + geom_line() + facet_wrap('~path',ncol=3,scales='free_x') + ylim(-0.5,0.5) + scale_color_manual({'All alleles':'gray',"Neutral + deleterious":'#ab2710'}) + theme_bw() + theme(legend_position='bottom'));p
# Out:
# /home/jmurga/.conda/lib/python3.8/site-packages/plotnine/facets/facet.py:555: PlotnineWarning: If you need more space for the y-axis tick text use ... + theme(subplots_adjust={'hspace': 0.25}). Choose an appropriate value for 'hspace'
# <ggplot: (8745473514578)>

# %%
ggsave(p,filename=PATH + "/results/simulations/slim/isolation/isolationRecaledSimulations.svg")

# %%
df,dfAlpha = saveSimulatedAlphas(table=simTable,cumulative=False)

# %%
dfAlpha['B'] = round(dfAlpha['B'],3)
dfAlpha['group'] = dfAlpha.path + ": " + dfAlpha.sfs
dfAlpha['path']  = pd.Categorical(dfAlpha.path, categories=pd.unique(dfAlpha.path))
plt.options.figure_size=(10,7)
p = (ggplot(dfAlpha, aes(x='f',y='alphas',color='sfs')) + geom_line() + facet_wrap('~path',ncol=3,scales='free_x') + ylim(-0.5,0.5) + scale_color_manual({'All alleles':'gray',"Neutral + deleterious":'#ab2710'}) + theme_bw() + theme(legend_position='bottom'));p
# Out:
# /home/jmurga/.conda/lib/python3.8/site-packages/plotnine/facets/facet.py:555: PlotnineWarning: If you need more space for the y-axis tick text use ... + theme(subplots_adjust={'hspace': 0.25}). Choose an appropriate value for 'hspace'
# <ggplot: (8745471045783)>
